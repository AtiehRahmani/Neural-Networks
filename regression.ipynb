# %% [markdown]
# # Regression using Neural Networks

# %% [markdown]
# ## Creating data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
data=make_regression(n_samples=1000,n_features=5,noise=.2,random_state=42)

# %%
X=data[0]
y=data[1]

# %%
X[0]
# Out:
# array([ 2.05654356,  0.60685059,  0.48268789, -1.13088844,  0.42009449])

# %%
y[0]
# Out:
# 74.8638525346159

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %% [markdown]
# ## train-test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2)

# %%
X_train.shape
# Out:
# (800, 5)

# %%
X_test.shape
# Out:
# (200, 5)

# %% [markdown]
# ## Building NN

# %%
import tensorflow as tf

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(units=16,activation='relu'),
    tf.keras.layers.Dense(units=16,activation='relu'),
    tf.keras.layers.Dense(units=1,activation='linear')
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │              96 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 385 (1.50 KB)
#  Trainable params: 385 (1.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Using add() function

# %%
model=tf.keras.models.Sequential()
model.add( tf.keras.layers.Input(shape=(5,)))
model.add(tf.keras.layers.Dense(units=16,activation='relu'))
model.add(tf.keras.layers.Dense(units=16,activation='relu'))
model.add(tf.keras.layers.Dense(units=1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 16)                  │              96 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 385 (1.50 KB)
#  Trainable params: 385 (1.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## compiling model

# %%
loss=tf.losses.MeanSquaredError()
opt=tf.optimizers.Adam()
model.compile(loss=loss,optimizer=opt)

# %%
model.fit(X_train,y_train,validation_split=.1,epochs=100,batch_size=50,verbose=2)
# Out:
# Epoch 1/100
# 15/15 - 0s - 16ms/step - loss: 0.1072 - val_loss: 0.1233
# Epoch 2/100
# 15/15 - 0s - 11ms/step - loss: 0.1045 - val_loss: 0.1153
# Epoch 3/100
# 15/15 - 0s - 9ms/step - loss: 0.1022 - val_loss: 0.1179
# Epoch 4/100
# 15/15 - 0s - 9ms/step - loss: 0.1050 - val_loss: 0.1102
# Epoch 5/100
# 15/15 - 0s - 9ms/step - loss: 0.1003 - val_loss: 0.1104
# Epoch 6/100
# 15/15 - 0s - 9ms/step - loss: 0.0982 - val_loss: 0.1101
# Epoch 7/100
# 15/15 - 0s - 9ms/step - loss: 0.1003 - val_loss: 0.1067
# Epoch 8/100
# 15/15 - 0s - 9ms/step - loss: 0.1002 - val_loss: 0.1080
# Epoch 9/100
# 15/15 - 0s - 11ms/step - loss: 0.1017 - val_loss: 0.1074
# Epoch 10/100
# 15/15 - 0s - 11ms/step - loss: 0.0969 - val_loss: 0.1064
# Epoch 11/100
# 15/15 - 0s - 9ms/step - loss: 0.1010 - val_loss: 0.1075
# Epoch 12/100
# 15/15 - 0s - 9ms/step - loss: 0.0988 - val_loss: 0.1075
# Epoch 13/100
# 15/15 - 0s - 13ms/step - loss: 0.0960 - val_loss: 0.1064
# Epoch 14/100
# 15/15 - 0s - 19ms/step - loss: 0.0947 - val_loss: 0.1095
# Epoch 15/100
# 15/15 - 0s - 8ms/step - loss: 0.0957 - val_loss: 0.1022
# Epoch 16/100
# 15/15 - 0s - 10ms/step - loss: 0.0936 - val_loss: 0.1040
# Epoch 17/100
# 15/15 - 0s - 9ms/step - loss: 0.0935 - val_loss: 0.1040
# Epoch 18/100
# 15/15 - 0s - 8ms/step - loss: 0.0947 - val_loss: 0.1053
# Epoch 19/100
# 15/15 - 0s - 10ms/step - loss: 0.0929 - val_loss: 0.1029
# Epoch 20/100
# 15/15 - 0s - 9ms/step - loss: 0.0936 - val_loss: 0.1015
# Epoch 21/100
# 15/15 - 0s - 8ms/step - loss: 0.0949 - val_loss: 0.0999
# Epoch 22/100
# 15/15 - 0s - 9ms/step - loss: 0.0939 - val_loss: 0.1021
# Epoch 23/100
# 15/15 - 0s - 8ms/step - loss: 0.0919 - val_loss: 0.0992
# Epoch 24/100
# 15/15 - 0s - 8ms/step - loss: 0.0910 - val_loss: 0.0997
# Epoch 25/100
# 15/15 - 0s - 9ms/step - loss: 0.0914 - val_loss: 0.1025
# Epoch 26/100
# 15/15 - 0s - 12ms/step - loss: 0.0896 - val_loss: 0.0982
# Epoch 27/100
# 15/15 - 0s - 12ms/step - loss: 0.0891 - val_loss: 0.0968
# Epoch 28/100
# 15/15 - 0s - 11ms/step - loss: 0.0883 - val_loss: 0.0991
# Epoch 29/100
# 15/15 - 0s - 11ms/step - loss: 0.0920 - val_loss: 0.0981
# Epoch 30/100
# 15/15 - 0s - 9ms/step - loss: 0.0885 - val_loss: 0.0968
# Epoch 31/100
# 15/15 - 0s - 9ms/step - loss: 0.0881 - val_loss: 0.0991
# Epoch 32/100
# 15/15 - 0s - 8ms/step - loss: 0.0859 - val_loss: 0.0995
# Epoch 33/100
# 15/15 - 0s - 8ms/step - loss: 0.0876 - val_loss: 0.1012
# Epoch 34/100
# 15/15 - 0s - 8ms/step - loss: 0.0875 - val_loss: 0.1041
# Epoch 35/100
# 15/15 - 0s - 9ms/step - loss: 0.0873 - val_loss: 0.0954
# Epoch 36/100
# 15/15 - 0s - 8ms/step - loss: 0.0899 - val_loss: 0.0997
# Epoch 37/100
# 15/15 - 0s - 8ms/step - loss: 0.0863 - val_loss: 0.0943
# Epoch 38/100
# 15/15 - 0s - 9ms/step - loss: 0.0851 - val_loss: 0.0949
# Epoch 39/100
# 15/15 - 0s - 8ms/step - loss: 0.0840 - val_loss: 0.0950
# Epoch 40/100
# 15/15 - 0s - 8ms/step - loss: 0.0845 - val_loss: 0.1021
# Epoch 41/100
# 15/15 - 0s - 8ms/step - loss: 0.0917 - val_loss: 0.0915
# Epoch 42/100
# 15/15 - 0s - 9ms/step - loss: 0.0865 - val_loss: 0.1005
# Epoch 43/100
# 15/15 - 0s - 8ms/step - loss: 0.0969 - val_loss: 0.0942
# Epoch 44/100
# 15/15 - 0s - 8ms/step - loss: 0.0881 - val_loss: 0.0994
# Epoch 45/100
# 15/15 - 0s - 8ms/step - loss: 0.0878 - val_loss: 0.0976
# Epoch 46/100
# 15/15 - 0s - 9ms/step - loss: 0.0836 - val_loss: 0.0941
# Epoch 47/100
# 15/15 - 0s - 8ms/step - loss: 0.0817 - val_loss: 0.0933
# Epoch 48/100
# 15/15 - 0s - 8ms/step - loss: 0.0809 - val_loss: 0.0952
# Epoch 49/100
# 15/15 - 0s - 8ms/step - loss: 0.0839 - val_loss: 0.0918
# Epoch 50/100
# 15/15 - 0s - 8ms/step - loss: 0.0819 - val_loss: 0.0903
# Epoch 51/100
# 15/15 - 0s - 8ms/step - loss: 0.0818 - val_loss: 0.0925
# Epoch 52/100
# 15/15 - 0s - 8ms/step - loss: 0.0810 - val_loss: 0.0906
# Epoch 53/100
# 15/15 - 0s - 8ms/step - loss: 0.0806 - val_loss: 0.0872
# Epoch 54/100
# 15/15 - 0s - 8ms/step - loss: 0.0837 - val_loss: 0.0890
# Epoch 55/100
# 15/15 - 0s - 8ms/step - loss: 0.0820 - val_loss: 0.0897
# Epoch 56/100
# 15/15 - 0s - 8ms/step - loss: 0.0798 - val_loss: 0.1004
# Epoch 57/100
# 15/15 - 0s - 8ms/step - loss: 0.0801 - val_loss: 0.0907
# Epoch 58/100
# 15/15 - 0s - 8ms/step - loss: 0.0760 - val_loss: 0.0912
# Epoch 59/100
# 15/15 - 0s - 13ms/step - loss: 0.0772 - val_loss: 0.0883
# Epoch 60/100
# 15/15 - 0s - 25ms/step - loss: 0.0752 - val_loss: 0.0887
# Epoch 61/100
# 15/15 - 0s - 8ms/step - loss: 0.0795 - val_loss: 0.0842
# Epoch 62/100
# 15/15 - 0s - 9ms/step - loss: 0.0756 - val_loss: 0.0884
# Epoch 63/100
# 15/15 - 0s - 9ms/step - loss: 0.0735 - val_loss: 0.0845
# Epoch 64/100
# 15/15 - 0s - 10ms/step - loss: 0.0780 - val_loss: 0.0884
# Epoch 65/100
# 15/15 - 0s - 9ms/step - loss: 0.0773 - val_loss: 0.0872
# Epoch 66/100
# 15/15 - 0s - 9ms/step - loss: 0.0735 - val_loss: 0.0867
# Epoch 67/100
# 15/15 - 0s - 9ms/step - loss: 0.0776 - val_loss: 0.0875
# Epoch 68/100
# 15/15 - 0s - 10ms/step - loss: 0.0790 - val_loss: 0.0875
# Epoch 69/100
# 15/15 - 0s - 9ms/step - loss: 0.0766 - val_loss: 0.0894
# Epoch 70/100
# 15/15 - 0s - 9ms/step - loss: 0.0757 - val_loss: 0.0948
# Epoch 71/100
# 15/15 - 0s - 10ms/step - loss: 0.0742 - val_loss: 0.0845
# Epoch 72/100
# 15/15 - 0s - 11ms/step - loss: 0.0721 - val_loss: 0.0827
# Epoch 73/100
# 15/15 - 0s - 24ms/step - loss: 0.0720 - val_loss: 0.0864
# Epoch 74/100
# 15/15 - 0s - 9ms/step - loss: 0.0724 - val_loss: 0.0876
# Epoch 75/100
# 15/15 - 0s - 9ms/step - loss: 0.0726 - val_loss: 0.0830
# Epoch 76/100
# 15/15 - 0s - 12ms/step - loss: 0.0712 - val_loss: 0.0848
# Epoch 77/100
# 15/15 - 0s - 10ms/step - loss: 0.0808 - val_loss: 0.0999
# Epoch 78/100
# 15/15 - 0s - 9ms/step - loss: 0.0799 - val_loss: 0.0875
# Epoch 79/100
# 15/15 - 0s - 10ms/step - loss: 0.0800 - val_loss: 0.0902
# Epoch 80/100
# 15/15 - 0s - 9ms/step - loss: 0.0740 - val_loss: 0.0943
# Epoch 81/100
# 15/15 - 0s - 9ms/step - loss: 0.0725 - val_loss: 0.0831
# Epoch 82/100
# 15/15 - 0s - 12ms/step - loss: 0.0742 - val_loss: 0.0813
# Epoch 83/100
# 15/15 - 0s - 9ms/step - loss: 0.0690 - val_loss: 0.0888
# Epoch 84/100
# 15/15 - 0s - 9ms/step - loss: 0.0714 - val_loss: 0.0816
# Epoch 85/100
# 15/15 - 0s - 9ms/step - loss: 0.0679 - val_loss: 0.0858
# Epoch 86/100
# 15/15 - 0s - 9ms/step - loss: 0.0715 - val_loss: 0.0872
# Epoch 87/100
# 15/15 - 0s - 8ms/step - loss: 0.0738 - val_loss: 0.0826
# Epoch 88/100
# 15/15 - 0s - 9ms/step - loss: 0.0701 - val_loss: 0.0799
# Epoch 89/100
# 15/15 - 0s - 8ms/step - loss: 0.0707 - val_loss: 0.0811
# Epoch 90/100
# 15/15 - 0s - 8ms/step - loss: 0.0714 - val_loss: 0.0875
# Epoch 91/100
# 15/15 - 0s - 8ms/step - loss: 0.0735 - val_loss: 0.0835
# Epoch 92/100
# 15/15 - 0s - 9ms/step - loss: 0.0682 - val_loss: 0.0819
# Epoch 93/100
# 15/15 - 0s - 11ms/step - loss: 0.0668 - val_loss: 0.0857
# Epoch 94/100
# 15/15 - 0s - 11ms/step - loss: 0.0667 - val_loss: 0.0807
# Epoch 95/100
# 15/15 - 0s - 11ms/step - loss: 0.0659 - val_loss: 0.0809
# Epoch 96/100
# 15/15 - 0s - 21ms/step - loss: 0.0682 - val_loss: 0.0822
# Epoch 97/100
# 15/15 - 0s - 9ms/step - loss: 0.0688 - val_loss: 0.0844
# Epoch 98/100
# 15/15 - 0s - 9ms/step - loss: 0.0665 - val_loss: 0.0855
# Epoch 99/100
# 15/15 - 0s - 8ms/step - loss: 0.0669 - val_loss: 0.0795
# Epoch 100/100
# 15/15 - 0s - 9ms/step - loss: 0.0650 - val_loss: 0.0764

# %%
model.evaluate(X_train,y_train)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0637
# 0.0636960119009018

# %%
model.evaluate(X_test,y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0906
# 0.09056555479764938

# %%
y_pred=model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
plt.scatter(y_pred,range(200),color='blue')
plt.scatter(y_test,range(200),color='red')
plt.show()

# %% [markdown]
# # The END
